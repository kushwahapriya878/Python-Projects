# %% [markdown]
# <a href="https://colab.research.google.com/github/kushwahapriya878/Python-Projects/blob/main/Zomato_Data_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Zomato Data Analysis**

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading data set
df=pd.read_csv('Zomato data .csv')
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.shape
# Out:
# (148, 7)

# %%
df.size
# Out:
# 1036

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.tail()
# Out:
#                  name online_order book_table   rate  votes  \
# 143  Melting Melodies           No         No  3.3/5      0
# 144   New Indraprasta           No         No  3.3/5      0
# 145      Anna Kuteera          Yes         No  4.0/5    771
# 146            Darbar           No         No  3.0/5     98
# 147     Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %% [markdown]
# # Insight
# *   Date set containg 148 rows and 7 features.
# *   5 features are containing categorical value and two features are containing numerical value.

# %%
df.head(3)
# Out:
#               name online_order book_table   rate  votes  \
# 0            Jalsa          Yes        Yes  4.1/5    775
# 1   Spice Elephant          Yes         No  4.1/5    787
# 2  San Churro Cafe          Yes         No  3.8/5    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %%
#converting data datatype of rate column
def handleRate(x):
  x=str(x).split('/')
  x=x[0]
  return float(x)

df['rate']=df['rate'].apply(handleRate)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
df.describe()
# Out:
#              rate        votes  approx_cost(for two people)
# count  148.000000   148.000000                   148.000000
# mean     3.633108   264.810811                   418.243243
# std      0.402271   653.676951                   223.085098
# min      2.600000     0.000000                   100.000000
# 25%      3.300000     6.750000                   200.000000
# 50%      3.700000    43.500000                   400.000000
# 75%      3.900000   221.750000                   600.000000
# max      4.600000  4884.000000                   950.000000

# %%
df.describe(include='object')
# Out:
#                    name online_order book_table listed_in(type)
# count               148          148        148             148
# unique              145            2          2               4
# top     San Churro Cafe           No         No          Dining
# freq                  2           90        140             110

# %% [markdown]
# # **Checking Missing Value**

# %%
df.isna().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %% [markdown]
# *   There are no missing value present in the data set

# %% [markdown]
# #Exploring listed in type

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='listed_in(type)')
plt.xlabel('Type of Restaurant')
plt.show()

# %% [markdown]
# **Insight**
#
#
# *   Mejority of restaurant fall into Dining category

# %% [markdown]
# # Total votes by restaurant type

# %%
restaurant_votes_df=df.groupby(by='listed_in(type)')['votes'].sum()
restaurant_votes_df=pd.DataFrame({'votes':restaurant_votes_df})
restaurant_votes_df
# Out:
#                  votes
# listed_in(type)
# Buffet            3028
# Cafes             6434
# Dining           20363
# other             9367

# %%
plt.figure(figsize=(8,4))
plt.plot(restaurant_votes_df, c='green', marker='o')
plt.xlabel('Type of Restaurant', c='black', size=20)
plt.ylabel('Votes', c='black', size=20)
plt.show()

# %% [markdown]
# **Insight**
# *  As per above analysis Dining type restaurant is more prefered by users.

# %% [markdown]
# # Checking online and offline order

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=df, x='online_order')
plt.xlabel('Online and Ofline order count', c='black', size=15)
plt.show()

# %% [markdown]
#  **Insight**
#
# *  As per above analysis most restaurant are not accepting online order.

# %% [markdown]
# # Checking distribution of rating

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df, x='rate', bins=10)
plt.title('Rating Distribution')
plt.show()

# %% [markdown]
# **Insight**
# *  Mejority of restaurant received rating range between 3.5 to 4

# %% [markdown]
# # Checking approx_cost(for two people)

# %%
df['approx_cost(for two people)'].value_counts()
# Out:
# approx_cost(for two people)
# 300    23
# 200    16
# 150    16
# 400    15
# 500    14
# 600    13
# 800    12
# 100     6
# 450     6
# 250     6
# 700     5
# 550     3
# 750     3
# 350     3
# 900     2
# 850     2
# 650     2
# 950     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='approx_cost(for two people)')
plt.title('Cost per pair')
plt.show()

# %% [markdown]
# **Insight**
#
# * Majority of pairs like restaurant approx cost 300 follwed by 200,150, 400.

# %% [markdown]
# # Checking whether online order receive higher rating or offline order?

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df, x='online_order', y='rate')
plt.show()

# %% [markdown]
# **Insight**
# *  As per the above analysis online orders are recieveing higher rating than offline order

# %% [markdown]
# # Checking correlation between features

# %%
df.drop(columns=['name', 'online_order', 'book_table', 'listed_in(type)']).corr()
# Out:
#                                  rate     votes  approx_cost(for two people)
# rate                         1.000000  0.489844                     0.275216
# votes                        0.489844  1.000000                     0.324372
# approx_cost(for two people)  0.275216  0.324372                     1.000000

# %%
pivot_table = df.pivot_table(index='listed_in(type)', columns='online_order', aggfunc='size', fill_value=0)
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt='d')
plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()

# %% [markdown]
# **Insight**
# * As per above analysis Dining restaurant first accept offline order, Cafes are first accept online oredr
